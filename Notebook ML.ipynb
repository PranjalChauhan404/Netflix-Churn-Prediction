# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_customer_churn.csv")
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# 0      Gift Card                   1                    0.49         Action
# 1      Gift Card                   5                    0.03         Sci-Fi
# 2         Crypto                   2                    1.48          Drama
# 3         Crypto                   2                    0.35         Horror
# 4         Crypto                   2                    0.13         Action

# %%
df.shape
# Out:
# (5000, 14)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'subscription_type', 'watch_hours',
#        'last_login_days', 'region', 'device', 'monthly_fee', 'churned',
#        'payment_method', 'number_of_profiles', 'avg_watch_time_per_day',
#        'favorite_genre'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   object
#  1   age                     5000 non-null   int64
#  2   gender                  5000 non-null   object
#  3   subscription_type       5000 non-null   object
#  4   watch_hours             5000 non-null   float64
#  5   last_login_days         5000 non-null   int64
#  6   region                  5000 non-null   object
#  7   device                  5000 non-null   object
#  8   monthly_fee             5000 non-null   float64
#  9   churned                 5000 non-null   int64
#  10  payment_method          5000 non-null   object
#  11  number_of_profiles      5000 non-null   int64
#  12  avg_watch_time_per_day  5000 non-null   float64
#  13  favorite_genre          5000 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 547.0+ KB

# %%
df.describe()
# Out:
#                age  watch_hours  last_login_days  monthly_fee      churned  \
# count  5000.000000  5000.000000      5000.000000  5000.000000  5000.000000
# mean     43.847400    11.649450        30.089800    13.683400     0.503000
# std      15.501128    12.014654        17.536078     3.692062     0.500041
# min      18.000000     0.010000         0.000000     8.990000     0.000000
# 25%      30.000000     3.337500        15.000000     8.990000     0.000000
# 50%      44.000000     8.000000        30.000000    13.990000     1.000000
# 75%      58.000000    16.030000        45.000000    17.990000     1.000000
# max      70.000000   110.400000        60.000000    17.990000     1.000000
#
#        number_of_profiles  avg_watch_time_per_day
# count         5000.000000             5000.000000
# mean             3.024400                0.874800
# std              1.415841                2.619824
# min              1.000000                0.000000
# 25%              2.000000                0.110000
# 50%              3.000000                0.290000
# 75%              4.000000                0.720000
# max              5.000000               98.420000

# %%
df.describe(include="object")
# Out:
#                                  customer_id  gender subscription_type  \
# count                                   5000    5000              5000
# unique                                  5000       3                 3
# top     a9b75100-82a8-427a-a208-72f24052884a  Female           Premium
# freq                                       1    1711              1693
#
#                region  device payment_method favorite_genre
# count            5000    5000           5000           5000
# unique              6       5              5              7
# top     South America  Tablet     Debit Card          Drama
# freq              873    1048           1030            731

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# customer_id: 5000
# age: 53
# gender: 3
# subscription_type: 3
# watch_hours: 2343
# last_login_days: 61
# region: 6
# device: 5
# monthly_fee: 3
# churned: 2
# payment_method: 5
# number_of_profiles: 5
# avg_watch_time_per_day: 505
# favorite_genre: 7

# %%
#STADE 1 : EDA

# %%
#Target Variables Analysis
plt.figure(figsize=(5,4))
sns.countplot(x="churned", data=df)
plt.title("Customer Churn Distribution")
plt.show()

# %%
df["churned"].value_counts(normalize=True)*100
# Out:
# churned
# 1    50.3
# 0    49.7
# Name: proportion, dtype: float64

# %%
#Univariate Ananlysis
numerical_cols = [
    'age',
    'watch_hours',
    'last_login_days',
    'number_of_profiles',
    'avg_watch_time_per_day'
]

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(col)
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,2))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,2))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
categorical_cols = [
    'gender',
    'subscription_type',
    'region',
    'device',
    'payment_method',
    'favorite_genre'
]

# %%
for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=45)
    plt.title(col)
    plt.show()

# %%
categorical_cols = [
    'gender',
    'subscription_type',
    'region',
    'device',
    'payment_method',
    'favorite_genre'
]

for col in categorical_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col, hue='churned', data=df)
    plt.xticks(rotation=45)
    plt.title(f"{col} vs Churn")
    plt.show()

# %%
numerical_cols = [
    'age',
    'watch_hours',
    'last_login_days',
    'monthly_fee',
    'number_of_profiles',
    'avg_watch_time_per_day'
]

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='churned', y=col, data=df)
    plt.title(f"{col} vs Churn")
    plt.show()

# %%
#STAGE 2 : Data Preprocessing & Feature Engineering

# %%
df.drop("customer_id", axis=1, inplace=True)

# %%
x = df.drop("churned", axis=1)
y = df["churned"]

# %%
x.select_dtypes(include="object").columns
# Out:
# Index(['gender', 'subscription_type', 'region', 'device', 'payment_method',
#        'favorite_genre'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in x.select_dtypes(include="object").columns:
    x[col] = le.fit_transform(x[col])

# %%
x.head()
# Out:
#    age  gender  subscription_type  watch_hours  last_login_days  region  \
# 0   51       2                  0        14.73               29       0
# 1   47       2                  2         0.70               19       2
# 2   27       0                  2        16.32               10       1
# 3   53       2                  1         4.51               12       4
# 4   56       2                  2         1.89               13       0
#
#    device  monthly_fee  payment_method  number_of_profiles  \
# 0       3         8.99               3                   1
# 1       2        13.99               3                   5
# 2       3        13.99               1                   2
# 3       3        17.99               1                   2
# 4       2        13.99               1                   2
#
#    avg_watch_time_per_day  favorite_genre
# 0                    0.49               0
# 1                    0.03               6
# 2                    1.48               3
# 3                    0.35               4
# 4                    0.13               0

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

numerical_cols = [
    "age",
    "watch_hours",
    "last_login_days",
    "monthly_fee",
    "number_of_profiles",
    "avg_watch_time_per_day"
]

scaler = StandardScaler()
x_train[numerical_cols] = scaler.fit_transform(x_train[numerical_cols])
x_test[numerical_cols] = scaler.transform(x_test[numerical_cols])

# %%
#Stage 3: Model Development

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(random_state=42)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import(accuracy_score, confusion_matrix, classification_report)

print("Accuracy: ",accuracy_score(y_test, y_pred))
print("\nConfusion Matrix\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report\n", classification_report(y_test, y_pred))
# Out:
# Accuracy:  0.877
#
# Confusion Matrix
#  [[431  67]
#  [ 56 446]]
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       498
#            1       0.87      0.89      0.88       502
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.88      0.88      0.88      1000

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap="Blues")
plt.title("Confusion MAtrix")
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, x_test, y_test)
plt.show()

# %%
#feature importance(coefficient) tell us how each feature influences CHURN.

feature_importance = pd.DataFrame({
    "Feature": x.columns,
    "Coefficient": model.coef_[0]
})
feature_importance.sort_values(
    by="Coefficient",
    ascending=False
)
# Out:
#                    Feature  Coefficient
# 4          last_login_days     2.106347
# 5                   region     0.041792
# 0                      age     0.013529
# 11          favorite_genre     0.001226
# 8           payment_method    -0.019925
# 6                   device    -0.021488
# 1                   gender    -0.082518
# 7              monthly_fee    -0.571008
# 2        subscription_type    -0.587781
# 9       number_of_profiles    -0.972782
# 3              watch_hours    -3.405076
# 10  avg_watch_time_per_day    -4.364669

# %%
#Decision Trees
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_y_pred = dt_model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, dt_y_pred))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, dt_y_pred))

print("\nClassification Report\n")
print(classification_report(y_test, dt_y_pred))
# Out:
# Accuracy: 0.971
#
# Confusion Matrix
#
# [[481  17]
#  [ 12 490]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       498
#            1       0.97      0.98      0.97       502
#
#     accuracy                           0.97      1000
#    macro avg       0.97      0.97      0.97      1000
# weighted avg       0.97      0.97      0.97      1000

# %%
ConfusionMatrixDisplay.from_predictions(y_test, dt_y_pred, cmap="Blues")
plt.title("Decision Tree Confusion Matrix")
plt.show()

# %%
RocCurveDisplay.from_estimator(dt_model, x_test, y_test)
plt.show()

# %%
#feature importance
feature_importance_dt = pd.DataFrame({
    "Feature": x.columns, "Importance": dt_model.feature_importances_})

feature_importance_dt.sort_values(by="Importance", ascending=False)
# Out:
#                    Feature  Importance
# 10  avg_watch_time_per_day    0.592423
# 8           payment_method    0.089971
# 3              watch_hours    0.079716
# 9       number_of_profiles    0.077596
# 4          last_login_days    0.067355
# 2        subscription_type    0.036714
# 7              monthly_fee    0.035125
# 0                      age    0.005886
# 11          favorite_genre    0.005059
# 5                   region    0.004305
# 6                   device    0.003554
# 1                   gender    0.002297

# %%
#Random Forest

from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(x_test)

# %%
print("Accuracy Score:", accuracy_score(y_test, y_pred_rf))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("\nClassification Report:\n",classification_report(y_test, y_pred_rf))
# Out:
# Accuracy Score: 0.977
#
# Confusion Matrix:
#  [[489   9]
#  [ 14 488]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       498
#            1       0.98      0.97      0.98       502
#
#     accuracy                           0.98      1000
#    macro avg       0.98      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
RocCurveDisplay.from_estimator(rf_model, x_test, y_test)
plt.show()

# %%
feature_importance_rf = pd.DataFrame({"Feature": x.columns, "Importance": rf_model.feature_importances_})
feature_importance_rf.sort_values(by="Importance", ascending=False)
# Out:
#                    Feature  Importance
# 10  avg_watch_time_per_day    0.389767
# 3              watch_hours    0.211344
# 4          last_login_days    0.182379
# 9       number_of_profiles    0.064209
# 8           payment_method    0.038715
# 7              monthly_fee    0.023993
# 0                      age    0.022749
# 2        subscription_type    0.021728
# 11          favorite_genre    0.013272
# 5                   region    0.012546
# 6                   device    0.011312
# 1                   gender    0.007984

# %%
from xgboost import XGBClassifier
xgb_model = XGBClassifier(random_state=42, eval_metric="logloss")
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb_model.predict(x_test)

# %%
print("Accuracy Score:",accuracy_score(y_test, y_pred_xgb))
print("\nConfusion Matrix:\n",confusion_matrix(y_test, y_pred_xgb))
print("\nClassification Report:\n",classification_report(y_test, y_pred_xgb))
# Out:
# Accuracy Score: 0.995
#
# Confusion Matrix:
#  [[497   1]
#  [  4 498]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       498
#            1       1.00      0.99      1.00       502
#
#     accuracy                           0.99      1000
#    macro avg       1.00      1.00      0.99      1000
# weighted avg       1.00      0.99      1.00      1000

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_xgb, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
RocCurveDisplay.from_estimator(xgb_model, x_test, y_test)
plt.show()

# %%
feature_importance_xgb = pd.DataFrame({
    "Feature": x.columns, 
    "Importance": xgb_model.feature_importances_
})
feature_importance_xgb.sort_values(by="Importance", ascending=False)
# Out:
#                    Feature  Importance
# 10  avg_watch_time_per_day    0.575732
# 2        subscription_type    0.097379
# 9       number_of_profiles    0.082558
# 8           payment_method    0.074302
# 4          last_login_days    0.064766
# 3              watch_hours    0.062951
# 11          favorite_genre    0.010622
# 5                   region    0.009402
# 6                   device    0.008858
# 0                      age    0.005959
# 1                   gender    0.004693
# 7              monthly_fee    0.002778

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(x_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred_gb = gb_model.predict(x_test)

# %%
print("Accuracy Scores:", accuracy_score(y_test, y_pred_gb))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_gb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Accuracy Scores: 0.991
#
# Confusion Matrix:
#  [[496   2]
#  [  7 495]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       498
#            1       1.00      0.99      0.99       502
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_gb)
plt.title("Confusion Matrix")
plt.show()

# %%
RocCurveDisplay.from_estimator(gb_model, x_test, y_test)
plt.show()

# %%
feature_importance_gb = pd.DataFrame({
    "Feature": x.columns, 
    "Importance": gb_model.feature_importances_
})

feature_importance_gb.sort_values(by="Importance", ascending=False)
# Out:
#                    Feature  Importance
# 10  avg_watch_time_per_day    0.666588
# 3              watch_hours    0.096879
# 9       number_of_profiles    0.076848
# 4          last_login_days    0.074491
# 7              monthly_fee    0.035846
# 2        subscription_type    0.026227
# 8           payment_method    0.022923
# 11          favorite_genre    0.000119
# 0                      age    0.000079
# 1                   gender    0.000000
# 5                   region    0.000000
# 6                   device    0.000000

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "random_state": 42,
        "eval_metric": "logloss"
    }

    model = XGBClassifier(**params)

    score = cross_val_score(model, x_train, y_train, cv=5, scoring="accuracy").mean()

    return score

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)
# Out:
# [I 2026-08-07 23:58:07,032] A new study created in memory with name: no-name-46954bfb-8480-4fbc-b2a9-b0ff1784e50d
# [I 2026-08-07 23:58:09,616] Trial 0 finished with value: 0.9882500000000001 and parameters: {'n_estimators': 370, 'max_depth': 6, 'learning_rate': 0.08306784758675734, 'subsample': 0.6028524539888326, 'colsample_bytree': 0.7221426426701076, 'gamma': 2.6418406124932825}. Best is trial 0 with value: 0.9882500000000001.
# [I 2026-08-07 23:58:11,976] Trial 1 finished with value: 0.991 and parameters: {'n_estimators': 285, 'max_depth': 6, 'learning_rate': 0.1716192560181925, 'subsample': 0.9264836537601038, 'colsample_bytree': 0.7014650062823393, 'gamma': 0.38753973049617585}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:13,558] Trial 2 finished with value: 0.9882500000000001 and parameters: {'n_estimators': 247, 'max_depth': 7, 'learning_rate': 0.2861599677434954, 'subsample': 0.656715033317068, 'colsample_bytree': 0.7997742509467876, 'gamma': 3.2801071210486987}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:15,355] Trial 3 finished with value: 0.986 and parameters: {'n_estimators': 289, 'max_depth': 10, 'learning_rate': 0.23187019739871148, 'subsample': 0.8648431187531902, 'colsample_bytree': 0.9786574675836904, 'gamma': 4.524800555034124}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:16,807] Trial 4 finished with value: 0.98425 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.039264161753790855, 'subsample': 0.9704968285474588, 'colsample_bytree': 0.7859225510142993, 'gamma': 4.142875152694569}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:18,229] Trial 5 finished with value: 0.9894999999999999 and parameters: {'n_estimators': 137, 'max_depth': 6, 'learning_rate': 0.0960509229428716, 'subsample': 0.8952583730545272, 'colsample_bytree': 0.7546146007079626, 'gamma': 3.481117558661941}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:20,091] Trial 6 finished with value: 0.9907499999999999 and parameters: {'n_estimators': 230, 'max_depth': 3, 'learning_rate': 0.10192508117059657, 'subsample': 0.892767584561404, 'colsample_bytree': 0.9404890837886355, 'gamma': 0.2835831226012686}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:21,103] Trial 7 finished with value: 0.9872500000000001 and parameters: {'n_estimators': 136, 'max_depth': 7, 'learning_rate': 0.19165379919252631, 'subsample': 0.7882747311064491, 'colsample_bytree': 0.9197192406435633, 'gamma': 1.2922414315811763}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:22,741] Trial 8 finished with value: 0.9862499999999998 and parameters: {'n_estimators': 241, 'max_depth': 5, 'learning_rate': 0.19064540607899993, 'subsample': 0.7082170739336917, 'colsample_bytree': 0.7233990543952309, 'gamma': 3.936162599307085}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:25,683] Trial 9 finished with value: 0.9887499999999999 and parameters: {'n_estimators': 490, 'max_depth': 6, 'learning_rate': 0.16591312684779264, 'subsample': 0.9301351387848715, 'colsample_bytree': 0.6315467191588199, 'gamma': 2.6461908373458147}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:29,103] Trial 10 finished with value: 0.9657500000000001 and parameters: {'n_estimators': 450, 'max_depth': 3, 'learning_rate': 0.013183128934528138, 'subsample': 0.7904599993853492, 'colsample_bytree': 0.6170058762383455, 'gamma': 0.17907993765441108}. Best is trial 1 with value: 0.991.
# [I 2026-08-07 23:58:32,302] Trial 11 finished with value: 0.993 and parameters: {'n_estimators': 323, 'max_depth': 3, 'learning_rate': 0.1303297025044888, 'subsample': 0.8378220568271012, 'colsample_bytree': 0.8673140236882316, 'gamma': 0.06977140326320108}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:35,128] Trial 12 finished with value: 0.991 and parameters: {'n_estimators': 344, 'max_depth': 4, 'learning_rate': 0.1414442141039353, 'subsample': 0.8262059826963889, 'colsample_bytree': 0.8543923120570945, 'gamma': 1.1695779701470388}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:37,603] Trial 13 finished with value: 0.9877499999999999 and parameters: {'n_estimators': 378, 'max_depth': 8, 'learning_rate': 0.23763717486596153, 'subsample': 0.9960017611483657, 'colsample_bytree': 0.8733125104654191, 'gamma': 1.0643437673573748}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:39,911] Trial 14 finished with value: 0.9915 and parameters: {'n_estimators': 310, 'max_depth': 4, 'learning_rate': 0.13526153817372863, 'subsample': 0.7515921089835114, 'colsample_bytree': 0.6787144234233293, 'gamma': 0.7115706425672887}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:42,799] Trial 15 finished with value: 0.9914999999999999 and parameters: {'n_estimators': 415, 'max_depth': 4, 'learning_rate': 0.13200352639011065, 'subsample': 0.7271314812081537, 'colsample_bytree': 0.6740253951731878, 'gamma': 1.8958396791600964}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:45,518] Trial 16 finished with value: 0.9927499999999998 and parameters: {'n_estimators': 317, 'max_depth': 4, 'learning_rate': 0.06620321089028991, 'subsample': 0.7415486056528299, 'colsample_bytree': 0.8495084573607159, 'gamma': 0.7530483957219389}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:48,444] Trial 17 finished with value: 0.98925 and parameters: {'n_estimators': 198, 'max_depth': 3, 'learning_rate': 0.058894412328832246, 'subsample': 0.6696020141055329, 'colsample_bytree': 0.842299028036315, 'gamma': 1.753407871773305}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:53,239] Trial 18 finished with value: 0.9905000000000002 and parameters: {'n_estimators': 329, 'max_depth': 5, 'learning_rate': 0.06051648996969744, 'subsample': 0.8266627188141566, 'colsample_bytree': 0.8887326193226406, 'gamma': 0.060475552141315995}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:56,857] Trial 19 finished with value: 0.98675 and parameters: {'n_estimators': 419, 'max_depth': 4, 'learning_rate': 0.01506685708046987, 'subsample': 0.7787758372474921, 'colsample_bytree': 0.8138770119913977, 'gamma': 1.7560679129650085}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:58:58,545] Trial 20 finished with value: 0.9907499999999999 and parameters: {'n_estimators': 186, 'max_depth': 5, 'learning_rate': 0.11249336285196043, 'subsample': 0.8239519927415929, 'colsample_bytree': 0.9905909656468883, 'gamma': 0.7672774183673118}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:00,796] Trial 21 finished with value: 0.9922500000000001 and parameters: {'n_estimators': 292, 'max_depth': 4, 'learning_rate': 0.1352671261156878, 'subsample': 0.7364148960650223, 'colsample_bytree': 0.9117368763627252, 'gamma': 0.6468967276993944}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:02,982] Trial 22 finished with value: 0.9914999999999999 and parameters: {'n_estimators': 273, 'max_depth': 3, 'learning_rate': 0.07346353984252088, 'subsample': 0.6919220978283347, 'colsample_bytree': 0.9370993009081744, 'gamma': 0.6581403388583851}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:06,413] Trial 23 finished with value: 0.992 and parameters: {'n_estimators': 352, 'max_depth': 4, 'learning_rate': 0.11957174322394788, 'subsample': 0.7426358067958436, 'colsample_bytree': 0.9084896541049632, 'gamma': 1.4388910760011229}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:09,936] Trial 24 finished with value: 0.9914999999999999 and parameters: {'n_estimators': 324, 'max_depth': 5, 'learning_rate': 0.15228095876899483, 'subsample': 0.6171749130935278, 'colsample_bytree': 0.8400504437086171, 'gamma': 0.8408122236586764}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:14,653] Trial 25 finished with value: 0.9905000000000002 and parameters: {'n_estimators': 392, 'max_depth': 3, 'learning_rate': 0.0424861392436013, 'subsample': 0.7728066495084404, 'colsample_bytree': 0.9656437911065539, 'gamma': 0.4733449787537167}. Best is trial 11 with value: 0.993.
# [I 2026-08-07 23:59:17,543] Trial 26 finished with value: 0.99375 and parameters: {'n_estimators': 304, 'max_depth': 4, 'learning_rate': 0.20634418923272307, 'subsample': 0.6665072882449372, 'colsample_bytree': 0.8826983311818579, 'gamma': 0.026898324924507055}. Best is trial 26 with value: 0.99375.
# [I 2026-08-07 23:59:19,925] Trial 27 finished with value: 0.99175 and parameters: {'n_estimators': 263, 'max_depth': 5, 'learning_rate': 0.22734018584684823, 'subsample': 0.6538509880390587, 'colsample_bytree': 0.7713127981657912, 'gamma': 0.05983538651300059}. Best is trial 26 with value: 0.99375.
# [I 2026-08-07 23:59:21,431] Trial 28 finished with value: 0.99075 and parameters: {'n_estimators': 210, 'max_depth': 3, 'learning_rate': 0.2672827998064265, 'subsample': 0.6365136134328865, 'colsample_bytree': 0.8210709945806514, 'gamma': 2.2048486650990107}. Best is trial 26 with value: 0.99375.
# [I 2026-08-07 23:59:23,689] Trial 29 finished with value: 0.993 and parameters: {'n_estimators': 366, 'max_depth': 4, 'learning_rate': 0.20919747052968998, 'subsample': 0.684539499854075, 'colsample_bytree': 0.880613113688489, 'gamma': 0.9627837418228923}. Best is trial 26 with value: 0.99375.

# %%
print("Best Accuracy:", study.best_value)
print("\nBest Parameters:\n", study.best_params)
# Out:
# Best Accuracy: 0.99375
#
# Best Parameters:
#  {'n_estimators': 304, 'max_depth': 4, 'learning_rate': 0.20634418923272307, 'subsample': 0.6665072882449372, 'colsample_bytree': 0.8826983311818579, 'gamma': 0.026898324924507055}

# %%
best_model = XGBClassifier(
    **study.best_params,
    randome_state=42,
    eval_metric="logloss"
)
best_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8826983311818579, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.026898324924507055, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.20634418923272307, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=304, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = best_model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.993
# [[496   2]
#  [  5 497]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       498
#            1       1.00      0.99      0.99       502
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
import joblib
joblib.dump(xgb_model, "Netflix_Churn_Model.pkl")
# Out:
# ['Netflix_Churn_Model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Netflix_Churn_Model.pkl', 'netflix_customer_churn.csv', 'scaler.pkl', 'Untitled Folder', 'Untitled.ipynb']
